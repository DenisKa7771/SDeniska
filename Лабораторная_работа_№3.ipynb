# %% [markdown]
# <a href="https://colab.research.google.com/github/DenisKa7771/SDeniska/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%963.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 
import pandas as pd
import numpy as np

# %%
# 2. 
df_init = pd.DataFrame({
    'ТЭС': ['Сургутская ГРЭС-2', 'Рефтинская ГРЭС', 'Костромская ГРЭС', 'Сургутская ГРЭС-1', 'Рязанская ГРЭС', 'Киришская ГРЭС', 'Конаковская ГРЭС', 'Ириклинская ГРЭС', 'Пермская ГРЭС','Ставропольская ГРЭС'],
    'Владелец': ['Э.Он Россия', 'Энел Россия', 'Интер РАО', 'Газпромэнергохолдинг', 'Газпромэнергохолдинг', 'Газпромэнергохолдинг', 'Энел Россия', 'Интер РАО', 'Интер РАО','Газпромэнергохолдинг'],
    'Регион': ['Ханты-Мансийский АО', 'Свердловская область', 'Костромская область', 'Ханты-Мансийский АО', 'Рязанская область', 'Ленинградская область', 'Тверская область', 'Оренбургская область', 'Пермский край','Ставропольский край'],
    'Мощность': [5.6, 3.8, 3.6,3.3,3.3,2.6,2.5,2.4,2.4,2.4]
})

df_init.head(10)
# Out:
#                    ТЭС              Владелец                 Регион  Мощность
# 0    Сургутская ГРЭС-2           Э.Он Россия    Ханты-Мансийский АО       5.6
# 1      Рефтинская ГРЭС           Энел Россия   Свердловская область       3.8
# 2     Костромская ГРЭС             Интер РАО    Костромская область       3.6
# 3    Сургутская ГРЭС-1  Газпромэнергохолдинг    Ханты-Мансийский АО       3.3
# 4       Рязанская ГРЭС  Газпромэнергохолдинг      Рязанская область       3.3
# 5       Киришская ГРЭС  Газпромэнергохолдинг  Ленинградская область       2.6
# 6     Конаковская ГРЭС           Энел Россия       Тверская область       2.5
# 7     Ириклинская ГРЭС             Интер РАО   Оренбургская область       2.4
# 8        Пермская ГРЭС             Интер РАО          Пермский край       2.4
# 9  Ставропольская ГРЭС  Газпромэнергохолдинг    Ставропольский край       2.4

# %%
# 3. 
df_exted = df_init.append(pd.DataFrame({'ТЭС': ['Сургутская ГРЭС-2', 'Рефтинская ГРЭС', 'Костромская ГРЭС', 'Сургутская ГРЭС-1', 'Рязанская ГРЭС', 'Киришская ГРЭС', 'Конаковская ГРЭС', 'Ириклинская ГРЭС', 'Пермская ГРЭС','Ставропольская ГРЭС'], 'Владелец': ['Э.Он Россия', 'Энел Россия', 'Интер РАО', 'Газпромэнергохолдинг', 'Газпромэнергохолдинг', 'Газпромэнергохолдинг', 'Энел Россия', 'Интер РАО', 'Интер РАО','Газпромэнергохолдинг'], 'Регион': ['Ханты-Мансийский АО', 'Свердловская область', 'Костромская область', 'Ханты-Мансийский АО', 'Рязанская область', 'Ленинградская область', 'Тверская область', 'Оренбургская область', 'Пермский край','Ставропольский край'], 'Мощность': [5.6, 3.8, 3.6,3.3,3.3,2.6,2.5,2.4,2.4,2.4]}), ignore_index = True)

print(df_exted)
print()

print('Имена столбцов:', df_exted.columns.values)
# Out:
#                     ТЭС              Владелец                 Регион  Мощность
# 0     Сургутская ГРЭС-2           Э.Он Россия    Ханты-Мансийский АО       5.6
# 1       Рефтинская ГРЭС           Энел Россия   Свердловская область       3.8
# 2      Костромская ГРЭС             Интер РАО    Костромская область       3.6
# 3     Сургутская ГРЭС-1  Газпромэнергохолдинг    Ханты-Мансийский АО       3.3
# 4        Рязанская ГРЭС  Газпромэнергохолдинг      Рязанская область       3.3
# 5        Киришская ГРЭС  Газпромэнергохолдинг  Ленинградская область       2.6
# 6      Конаковская ГРЭС           Энел Россия       Тверская область       2.5
# 7      Ириклинская ГРЭС             Интер РАО   Оренбургская область       2.4
# 8         Пермская ГРЭС             Интер РАО          Пермский край       2.4
# 9   Ставропольская ГРЭС  Газпромэнергохолдинг    Ставропольский край       2.4
# 10    Сургутская ГРЭС-2           Э.Он Россия    Ханты-Мансийский АО       5.6
# ...

# %%
# 4. 
df_exted.insert(0, 'id', ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'g', 'k', 'l', 'm', 'n', 'o', 'p', 'q', 'r', 's', 't'])

print(df_exted)
print()

df_exted = df_exted.set_index('id')

print(df_exted)
# Out:
#    id                  ТЭС              Владелец                 Регион  \
# 0   a    Сургутская ГРЭС-2           Э.Он Россия    Ханты-Мансийский АО
# 1   b      Рефтинская ГРЭС           Энел Россия   Свердловская область
# 2   c     Костромская ГРЭС             Интер РАО    Костромская область
# 3   d    Сургутская ГРЭС-1  Газпромэнергохолдинг    Ханты-Мансийский АО
# 4   e       Рязанская ГРЭС  Газпромэнергохолдинг      Рязанская область
# 5   f       Киришская ГРЭС  Газпромэнергохолдинг  Ленинградская область
# 6   g     Конаковская ГРЭС           Энел Россия       Тверская область
# 7   h     Ириклинская ГРЭС             Интер РАО   Оренбургская область
# 8   i        Пермская ГРЭС             Интер РАО          Пермский край
# 9   g  Ставропольская ГРЭС  Газпромэнергохолдинг    Ставропольский край
# 10  k    Сургутская ГРЭС-2           Э.Он Россия    Ханты-Мансийский АО
# 11  l      Рефтинская ГРЭС           Энел Россия   Свердловская область
# ...

# %%
# 5. 
df_exted = df_exted.sort_values(['ТЭС'])
print(df_exted)
print()

df_exted = df_exted.sort_values(['Мощность'], ascending = True)
print(df_exted)
# Out:
#                     ТЭС              Владелец                 Регион  Мощность
# id
# r      Ириклинская ГРЭС             Интер РАО   Оренбургская область       2.4
# h      Ириклинская ГРЭС             Интер РАО   Оренбургская область       2.4
# f        Киришская ГРЭС  Газпромэнергохолдинг  Ленинградская область       2.6
# p        Киришская ГРЭС  Газпромэнергохолдинг  Ленинградская область       2.6
# g      Конаковская ГРЭС           Энел Россия       Тверская область       2.5
# q      Конаковская ГРЭС           Энел Россия       Тверская область       2.5
# c      Костромская ГРЭС             Интер РАО    Костромская область       3.6
# m      Костромская ГРЭС             Интер РАО    Костромская область       3.6
# i         Пермская ГРЭС             Интер РАО          Пермский край       2.4
# s         Пермская ГРЭС             Интер РАО          Пермский край       2.4
# b       Рефтинская ГРЭС           Энел Россия   Свердловская область       3.8
# ...

# %%
# 6. 
df_exted_2 = df_exted.copy()

df_exted_2['Выработка_за_2_часа'] = df_exted_2['Мощность'] * 2 #  За 2 часа


df_exted_2['Тип'] = np.where(df_exted_2['ТЭС'].str.find('ГРЭС') >= 0, 'ГРЭС', np.where(df_exted_2['ТЭС'].str.find('ГРЭС') >= 0, 'ГРЭС', '?'))

print(df_exted_2)
print()

df_exted_2['Проверка_расчетов'] =  df_exted_2['Выработка_за_2_часа'] / df_exted_2['Мощность'] == 2
print(df_exted_2)
# Out:
#                     ТЭС              Владелец                 Регион  \
# id
# r      Ириклинская ГРЭС             Интер РАО   Оренбургская область
# t   Ставропольская ГРЭС  Газпромэнергохолдинг    Ставропольский край
# g   Ставропольская ГРЭС  Газпромэнергохолдинг    Ставропольский край
# i         Пермская ГРЭС             Интер РАО          Пермский край
# s         Пермская ГРЭС             Интер РАО          Пермский край
# h      Ириклинская ГРЭС             Интер РАО   Оренбургская область
# q      Конаковская ГРЭС           Энел Россия       Тверская область
# g      Конаковская ГРЭС           Энел Россия       Тверская область
# p        Киришская ГРЭС  Газпромэнергохолдинг  Ленинградская область
# f        Киришская ГРЭС  Газпромэнергохолдинг  Ленинградская область
# e        Рязанская ГРЭС  Газпромэнергохолдинг      Рязанская область
# o        Рязанская ГРЭС  Газпромэнергохолдинг      Рязанская область
# ...

# %%
# 7. 
print(df_exted[(df_exted.Мощность > 3.) & (df_exted.Владелец != 'Газпромэнергохолдинг')])
print()
# Out:
#                   ТЭС     Владелец                Регион  Мощность
# id
# c    Костромская ГРЭС    Интер РАО   Костромская область       3.6
# m    Костромская ГРЭС    Интер РАО   Костромская область       3.6
# b     Рефтинская ГРЭС  Энел Россия  Свердловская область       3.8
# l     Рефтинская ГРЭС  Энел Россия  Свердловская область       3.8
# k   Сургутская ГРЭС-2  Э.Он Россия   Ханты-Мансийский АО       5.6
# a   Сургутская ГРЭС-2  Э.Он Россия   Ханты-Мансийский АО       5.6

# %%
# 8. 
print('Данные из третьей строки и третьего столбца')
print(df_exted_2.iloc[8 , 1])
print()
print('Данные из всех строк  и из столбцов со второго по четвертый включительно')
print(df_exted_2.iloc[:, 2 : 4])
print()
print('данные из нечетных строк и четвертого столбца')
print(df_exted_2.iloc[ : : 2, 4])
print()
# Out:
# Данные из третьей строки и третьего столбца
# Газпромэнергохолдинг
#
# Данные из всех строк  и из столбцов со второго по четвертый включительно
#                    Регион  Мощность
# id
# r    Оренбургская область       2.4
# t     Ставропольский край       2.4
# g     Ставропольский край       2.4
# i           Пермский край       2.4
# s           Пермский край       2.4
# h    Оренбургская область       2.4
# q        Тверская область       2.5
# g        Тверская область       2.5
# p   Ленинградская область       2.6
# f   Ленинградская область       2.6
# e       Рязанская область       3.3
# o       Рязанская область       3.3
# d     Ханты-Мансийский АО       3.3
# n     Ханты-Мансийский АО       3.3
# c     Костромская область       3.6
# m     Костромская область       3.6
# b    Свердловская область       3.8
# l    Свердловская область       3.8
# k     Ханты-Мансийский АО       5.6
# a     Ханты-Мансийский АО       5.6
#
# данные из нечетных строк и четвертого столбца
# ...

# %%
# 9. 
print(df_exted.groupby(['ТЭС'])['Мощность'].sum())
print()


print(df_exted.groupby(['ТЭС'])['Мощность'].max())
print()


print(df_exted.groupby(['Владелец', df_exted['Мощность'] > 3])['Мощность'].count())
print()
# Out:
# ТЭС
# Ириклинская ГРЭС        4.8
# Киришская ГРЭС          5.2
# Конаковская ГРЭС        5.0
# Костромская ГРЭС        7.2
# Пермская ГРЭС           4.8
# Рефтинская ГРЭС         7.6
# Рязанская ГРЭС          6.6
# Ставропольская ГРЭС     4.8
# Сургутская ГРЭС-1       6.6
# Сургутская ГРЭС-2      11.2
# Name: Мощность, dtype: float64
#
# ТЭС
# Ириклинская ГРЭС       2.4
# Киришская ГРЭС         2.6
# Конаковская ГРЭС       2.5
# Костромская ГРЭС       3.6
# Пермская ГРЭС          2.4
# Рефтинская ГРЭС        3.8
# Рязанская ГРЭС         3.3
# Ставропольская ГРЭС    2.4
# Сургутская ГРЭС-1      3.3
# Сургутская ГРЭС-2      5.6
# Name: Мощность, dtype: float64
#
# Владелец              Мощность
# Газпромэнергохолдинг  False       4
#                       True        4
# Интер РАО             False       4
#                       True        2
# Э.Он Россия           True        2
# Энел Россия           False       2
#                       True        2
# ...

# %%
# 10.
df_exted.groupby(['ТЭС'])['Мощность'].sum().plot(kind = 'barh')
print()

# %%
# 11. Другой пример графика - PieChart

# получить сумму значений по столбцам
gen = df_exted.groupby(['ТЭС']).sum()


# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = gen.index

fig1, ax1 = plt.subplots(figsize = (10, 10))
ax1.pie(gen['Мощность'] ,labels=gen.index, autopct = '%1.0f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-15180f809324> in <module>()
#       8 labels = gen.index
#       9
# ---> 10 fig1, ax1 = plt.subplots(figsize = (10, 10))
#      11 ax1.pie(gen['Мощность'] ,labels=gen.index, autopct = '%1.0f%%')
#      12 ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#
# NameError: name 'plt' is not defined

# %%
# 12.
df_del = df_exted.drop(df_exted[df_exted['Мощность'] < 3].index)
print(df_del)

# %%
# 13.
import pandas as pd

# %%
# 14.
import requests
from bs4 import BeautifulSoup

def create_url(date):
  url_begin = "https://so-ups.ru/functioning/ees/ees-indicators/ees-gen-consump-hour/?tx_mscdugraph_pi%5Bcontroller%5D=Graph&tx_mscdugraph_pi%5Baction%5D=fullview&tx_mscdugraph_pi%5BviewDate%5D="
  url_end = "&tx_mscdugraph_pi%5BviewKpo%5D=6100"
  return url_begin + date + url_end

def parse_consumption(date):
  url = create_url(date)
  soup = BeautifulSoup(requests.get(url).content, 'html.parser')
  full_txt = str(soup)
  text_list_datetime = full_txt[full_txt.find('data-datax=') + len('data-datax=') + 1 : full_txt.find('data-datay=') - 2].split(',')
  text_list_consumption = full_txt[full_txt.find('data-datay=') + len('data-datay=') + 1 : full_txt.find('data-datay1=') - 2].split(',')
  text_list_generation = full_txt[full_txt.find('data-datay1=') + len('data-datay1=') + 1 : full_txt.find('data-date=') - 2].split(',')
  df = pd.DataFrame([text_list_datetime, list(map(int, text_list_generation)), list(map(int, text_list_consumption))])
  return df.T

# %%
# 15.
df_power = parse_consumption('2022-01-01')
df_power = df_power.append(parse_consumption('2022-01-02'))
df_power = df_power.append(parse_consumption('2022-01-03'))
df_power

# %%
# 16.
df_power.columns = ['Время', 'Генерация (МВт)', 'Потребление (МВт)']


df_power = df_power.set_index('Время')


df_power['Генерация (МВт)'] = df_power['Генерация (МВт)'].astype('int')
df_power['Потребление (МВт)'] = df_power['Потребление (МВт)'].astype('int')


df_power['Разность (МВт)'] = df_power['Генерация (МВт)'] - df_power['Потребление (МВт)'] 
df_power

# %%
# 17.
import matplotlib.pyplot as plt

axes = df_power.plot(marker='.', figsize=(20, 10), subplots = True)

for _ in axes:
  _.grid(True)

axes = df_power[df_power.columns[: -1]].plot(marker='.', figsize=(20, 5), subplots = False)
axes.grid(True)

# %%
# 18. Для визуализации данных существует множество Python библиотек, обзор есть в https://colab.research.google.com/notebooks/charts.ipynb#scrollTo=QSMmdrrVLZ-N
# Рассмотрим одну из них - Bokeh https://docs.bokeh.org/en/latest/docs/user_guide/plotting.html
input_matrix = df_power.values
win = df_power.iloc[: ,2 ]
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

output_notebook()

p = figure(plot_width = 1500, plot_height = 400)

p.line(np.arange(len(win)), win, line_width = 2,color='green')
p.scatter(np.arange(len(win)), win)

show(p)

# %%
# 19. Подробнее работа с табличными данными pandas будет в следующей работе. Сейчас нужно перевести все в матрицу
# Здесь в дело вступает другая очень популярная и мощная python-библиотека - NumPy

input_matrix =df_power.values # перевод таблицы в матрицу
t=input_matrix[:,0]
G=input_matrix[:,1]
P=input_matrix[:,2]
R=G-P
print('размерность матрицы', input_matrix.shape)
print()

# %%
# 20. 
axes = df_power.iloc[ : 24, 1].plot(kind = 'bar', figsize=(24, 5), color = 'red')

for p in axes.patches:
  axes.annotate(str(p.get_height()), (p.get_x(), p.get_height() * 1.01))

axes.grid(True)

# %%
# 21. 
df_power.corr()

# %%
# 22. Другой пример графика - PieChart

# получить сумму значений по столбцам
gen = (df_power[: ]).sum(axis = 0)


# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = df_power.columns[ : ]

fig1, ax1 = plt.subplots(figsize = (10, 10))
ax1.pie(gen,labels =labels , autopct = '%1.0f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# 23.
df_power.plot(x = 'Генерация (МВт)', y = 'Потребление (МВт)', style='o')
df_power.plot(x = 'Генерация (МВт)', y = 'Разность (МВт)', style='o')

# %%
# 24. Чтение данных из Excel-файла (https://minenergo.gov.ru/activity/statistic)
df_init = pd.read_excel('https://drive.google.com/uc?export=download&id=1IFULWv72kGpZRDRpqRskm5NIM6AOCFPR', header = None)
df_init
# Out:
#              0         1
# 0   01.01.2013  103256.7
# 1   01.02.2013   91532.6
# 2   01.03.2013   97809.1
# 3   01.04.2013   85131.0
# 4   01.05.2013   79080.8
# ..         ...       ...
# 79  01.08.2019   83100.0
# 80  01.09.2019   84000.0
# 81  01.10.2019   93200.0
# 82  01.11.2019   98900.0
# 83  01.12.2019  104400.0
#
# [84 rows x 2 columns]

# %%
# 25. Вывод графика
axes = df_init.plot(marker='*', figsize=(20, 5), subplots = False,color='red')
axes.grid(True)
legend=dict(x=.5, xanchor="center")
title="Plot Title",
xaxis_title="Мощность"
yaxis_title="Время"

# %%
# 26. 
df_date = df_init[0].str.split('.', expand = True) 
print(df_date.head())
print()
df_gen = pd.DataFrame()

df_gen['Generation, mln MWt*h'] = df_init[1] / 1000 # перевод кВтч в МВтч
df_gen['Month_ID'] = df_date[1].astype(int) 
df_gen['Year'] = df_date[2].astype(int) 

print(df_gen.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9fd4ef8c6637> in <module>()
#       1 # 26.
# ----> 2 df_date = df_init[0].str.split('.', expand = True)
#       3 print(df_date.head())
#       4 print()
#       5 df_gen = pd.DataFrame()
#
# NameError: name 'df_init' is not defined

# %%
# 27. 
input_matrix = df_init.values
wind = df_init.iloc[: , 1]
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

output_notebook()

p = figure(plot_width = 1500, plot_height = 400)
p.xaxis.axis_label = 'Время'
p.yaxis.axis_label = 'Мощность'
p.line(np.arange(len(wind)), wind, line_width = 2,color='red')
p.scatter(np.arange(len(wind)), wind)

show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-88ae87bec1ae> in <module>()
#       1 # 27.
# ----> 2 input_matrix = df_init.values
#       3 wind = df_init.iloc[: , 1]
#       4 from bokeh.plotting import figure, output_file, show
#       5 from bokeh.io import output_notebook
#
# NameError: name 'df_init' is not defined

# %%
# 28. Статистика суммарной генерации по годам.
year_stat = df_gen.groupby(['Year'])['Generation, mln MWt*h'].sum()

print(year_stat)
print()

year_stat.plot(kind = 'bar')
print()

# %%
# 29. Статистика суммарной генерации по месяцам.
month_stat = df_gen.groupby(['Month_ID'])['Generation, mln MWt*h'].sum()

print(month_stat)
print()

month_stat.plot(kind = 'bar')
print()

# %%
# 30. Сортировка по возрастанию
month_stat.sort_values().plot(kind = 'bar')
print()

# %%
# 31. Подключение библиотек для интерактивного графика
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook
import numpy as np

output_notebook()

# %%
# 32. Построение графиков помесячной выработки за каждый год 
p = figure(plot_width = 800, plot_height = 400)

colors = ['magenta', 'red', 'yellow', 'green', 'cyan', 'blue', 'black']
for year in range(2013, 2020):
  
  values = df_gen[df_gen['Year'] == year]['Generation, mln MWt*h'].values 
  
  p.line(np.arange(1, 13), values, color = colors[year - 2013], legend_label = str(year), line_width = 1)

  p.circle(np.arange(1, 13), values, color = colors[year - 2013], alpha=0.5, size = 7)

show(p)
